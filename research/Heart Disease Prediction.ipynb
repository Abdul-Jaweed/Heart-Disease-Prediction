# %% [markdown]
# # Productionisation of Machine Learning Models (Model Serialization)

# %% [markdown]
# # Heart Disease Prediction

# %% [markdown]
# ### Problem Statement:
#
#  Health is real wealth in the pandemic time we all realized the brute effects of covid-19 on
#  all irrespective of any status. You are required to analyze this health and medical data for
#  better future preparation.
#
#  - From the database extract various information such as Heart disease rates, Heart disease by gender, by age.
#  - You can even compare attributes of the data set to extract necessary information.
#  - Make necessary dashboard with the best you can extract from the data.
#  - Use various visualization and features and make the best dashboard.
#  - Find key metrics and factors and show the meaningful relationships between attributes.

# %% [markdown]
# ## Data Set Information:
#
# This dataset contains details of the age,BP,cholestrol and about having heart disease or not.Using the attributes in the dataset we can predict heart diseae risk for an individual and identify the risk factors.
#
# This database contains 76 attributes, but all published experiments refer to using a subset of 14 of them. In particular,   the Cleveland database is the only one that has been used by ML researchers to this date. The "goal" field refers to the presence of heart disease in the patient. It is integer valued from 0 (no presence) to 4. Experiments with the Cleveland database have concentrated on simply attempting to distinguish presence (values 1,2,3,4) from absence (value 0).
#
# The names and social security numbers of the patients were recently removed from the database, replaced with dummy values.
#
# One file has been "processed", that one containing the Cleveland database. All four unprocessed files also exist in this directory.
#
# To see Test Costs (donated by Peter Turney), please see the folder "Costs"
#
# ### Attribute Information:
#
# Only 14 attributes used:
# 1. #3 (age)
# 2. #4 (sex)
# 3. #9 (cp)
# 4. #10 (trestbps)
# 5. #12 (chol)
# 6. #16 (fbs)
# 7. #19 (restecg)
# 8. #32 (thalach)
# 9. #38 (exang)
# 10. #40 (oldpeak)
# 11. #41 (slope)
# 12. #44 (ca)
# 13. #51 (thal)
# 14. #58 (num) (the predicted attribute)
#
# ### Complete attribute documentation:
#     1 id: patient identification number
#     2 ccf: social security number (I replaced this with a dummy value of 0)
#     3 age: age in years
#     4 sex: sex (1 = male; 0 = female)
#     5 painloc: chest pain location (1 = substernal; 0 = otherwise)
#     6 painexer (1 = provoked by exertion; 0 = otherwise)
#     7 relrest (1 = relieved after rest; 0 = otherwise)
#     8 pncaden (sum of 5, 6, and 7)
#     9 cp: chest pain type
#     -- Value 1: typical angina
#     -- Value 2: atypical angina
#     -- Value 3: non-anginal pain
#     -- Value 4: asymptomatic
#     10 trestbps: resting blood pressure (in mm Hg on admission to the hospital)
#     11 htn
#     12 chol: serum cholestoral in mg/dl
#     13 smoke: I believe this is 1 = yes; 0 = no (is or is not a smoker)
#     14 cigs (cigarettes per day)
#     15 years (number of years as a smoker)
#     16 fbs: (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#     17 dm (1 = history of diabetes; 0 = no such history)
#     18 famhist: family history of coronary artery disease (1 = yes; 0 = no)
#     19 restecg: resting electrocardiographic results
#     -- Value 0: normal
#     -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#     -- Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
#     20 ekgmo (month of exercise ECG reading)
#     21 ekgday(day of exercise ECG reading)
#     22 ekgyr (year of exercise ECG reading)
#     23 dig (digitalis used furing exercise ECG: 1 = yes; 0 = no)
#     24 prop (Beta blocker used during exercise ECG: 1 = yes; 0 = no)
#     25 nitr (nitrates used during exercise ECG: 1 = yes; 0 = no)
#     26 pro (calcium channel blocker used during exercise ECG: 1 = yes; 0 = no)
#     27 diuretic (diuretic used used during exercise ECG: 1 = yes; 0 = no)
#     28 proto: exercise protocol
#     1 = Bruce
#     2 = Kottus
#     3 = McHenry
#     4 = fast Balke
#     5 = Balke
#     6 = Noughton
#     7 = bike 150 kpa min/min (Not sure if "kpa min/min" is what was written!)
#     8 = bike 125 kpa min/min
#     9 = bike 100 kpa min/min
#     10 = bike 75 kpa min/min
#     11 = bike 50 kpa min/min
#     12 = arm ergometer
#     29 thaldur: duration of exercise test in minutes
#     30 thaltime: time when ST measure depression was noted
#     31 met: mets achieved
#     32 thalach: maximum heart rate achieved
#     33 thalrest: resting heart rate
#     34 tpeakbps: peak exercise blood pressure (first of 2 parts)
#     35 tpeakbpd: peak exercise blood pressure (second of 2 parts)
#     36 dummy
#     37 trestbpd: resting blood pressure
#     38 exang: exercise induced angina (1 = yes; 0 = no)
#     39 xhypo: (1 = yes; 0 = no)
#     40 oldpeak = ST depression induced by exercise relative to rest
#     41 slope: the slope of the peak exercise ST segment
#     -- Value 1: upsloping
#     -- Value 2: flat
#     -- Value 3: downsloping
#     42 rldv5: height at rest
#     43 rldv5e: height at peak exercise
#     44 ca: number of major vessels (0-3) colored by flourosopy
#     45 restckm: irrelevant
#     46 exerckm: irrelevant
#     47 restef: rest raidonuclid (sp?) ejection fraction
#     48 restwm: rest wall (sp?) motion abnormality
#     0 = none
#     1 = mild or moderate
#     2 = moderate or severe
#     3 = akinesis or dyskmem (sp?)
#     49 exeref: exercise radinalid (sp?) ejection fraction
#     50 exerwm: exercise wall (sp?) motion
#     51 thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#     52 thalsev: not used
#     53 thalpul: not used
#     54 earlobe: not used
#     55 cmo: month of cardiac cath (sp?) (perhaps "call")
#     56 cday: day of cardiac cath (sp?)
#     57 cyr: year of cardiac cath (sp?)
#     58 num: diagnosis of heart disease (angiographic disease status)
#     -- Value 0: < 50% diameter narrowing
#     -- Value 1: > 50% diameter narrowing
#     (in any major vessel: attributes 59 through 68 are vessels)
#     59 lmt
#     60 ladprox
#     61 laddist
#     62 diag
#     63 cxmain
#     64 ramus
#     65 om1
#     66 om2
#     67 rcaprox
#     68 rcadist
#     69 lvx1: not used
#     70 lvx2: not used
#     71 lvx3: not used
#     72 lvx4: not used
#     73 lvf: not used
#     74 cathef: not used
#     75 junk: not used
#     76 name: last name of patient (I replaced this with the dummy string "name")

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Loading Dataset**

# %%
df = pd.read_csv("heart_disease_dataset.csv")

# %%
# showing top five rows 

df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
# showing Last five rows

df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope      ca  thal  num
# 298      2       0     7    1
# 299      2       2     7    1
# 300      2       1     7    1
# 301      2       1     3    1
# 302      1 -100000     3    0

# %%
# showing 10 sample rows

df.sample(10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 175   57    1   4       152   274    0        0       88      1      1.2
# 183   59    1   1       178   270    0        2      145      0      4.2
# 194   68    0   3       120   211    0        2      115      0      1.5
# 79    58    1   4       150   270    0        2      111      1      0.8
# 108   61    1   4       120   260    0        0      140      1      3.6
# 230   52    0   3       136   196    0        2      169      0      0.1
# 222   39    0   3        94   199    0        0      179      0      0.0
# 290   67    1   3       152   212    0        2      150      0      0.8
# 242   49    0   4       130   269    0        0      163      0      0.0
# 199   59    1   1       160   273    0        2      125      0      0.0
#
#      slope  ca  thal  num
# 175      2   1     7    1
# 183      3   0     7    0
# 194      2   0     3    0
# 79       1   0     7    1
# 108      2   1     7    1
# ...

# %%
# printing all columns name

df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
# showing total rows and columns 

df.shape
# Out:
# (303, 14)

# %%
# printing information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  num       303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# checking null values

df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
# checking duplicated values

df.duplicated().sum()
# Out:
# 0

# %%
# printing statistical summary of dataset

df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660
# std      0.994971   22.875003    0.469794    1.161075    0.616226
# ...

# %%
# printing correlation of data

df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.097542  0.104139  0.284946  0.208950  0.118530
# sex      -0.097542  1.000000  0.010084 -0.064456 -0.199915  0.047862
# cp        0.104139  0.010084  1.000000 -0.036077  0.072319 -0.039975
# trestbps  0.284946 -0.064456 -0.036077  1.000000  0.130120  0.175340
# chol      0.208950 -0.199915  0.072319  0.130120  1.000000  0.009841
# fbs       0.118530  0.047862 -0.039975  0.175340  0.009841  1.000000
# restecg   0.148868  0.021647  0.067505  0.146560  0.171043  0.069564
# thalach  -0.393806 -0.048663 -0.334422 -0.045351 -0.003432 -0.007854
# exang     0.091661  0.146201  0.384060  0.064762  0.061310  0.025665
# oldpeak   0.203805  0.102173  0.202277  0.189171  0.046564  0.005747
# slope     0.161770  0.037533  0.152050  0.117382 -0.004062  0.059894
# ca        0.085766 -0.079361  0.019134 -0.010263  0.068128 -0.032997
# thal      0.017545  0.031518 -0.028985  0.017149  0.057866 -0.080552
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %% [markdown]
# ### Age Column

# %%
df.age.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 298    45
# 299    68
# 300    57
# 301    57
# 302    38
# Name: age, Length: 303, dtype: int64>

# %%
# checking the distribution of age columns

df.age.plot(kind='kde', figsize=(8,6), legend=True, title="Age Distribution")
plt.show()

# %%
# checking the outlier of age columns

df.age.plot(kind='box', figsize=(8,6), legend=True, title=("Ages Boxplot Visualization"))
plt.show()

# %%
# minimum age

df.age.min()
# Out:
# 29

# %%
# maximum age

df.age.max()
# Out:
# 77

# %%
# Mean Age

df.age.mean()
# Out:
# 54.43894389438944

# %%
# Median Age

df.age.median()
# Out:
# 56.0

# %%
# 25 % of the People come under 48 Age

df.age.quantile(0.25)
# Out:
# 48.0

# %%
# 50 % of the People come under 56 Age

df.age.quantile(0.50)
# Out:
# 56.0

# %%
# 75 % of the People come under 61 Age

df.age.quantile(0.75)
# Out:
# 61.0

# %% [markdown]
# ### Gender Column

# %%
df.sex.value_counts()
# Out:
# 1    206
# 0     97
# Name: sex, dtype: int64

# %% [markdown]
# - Male = 1
# - Female = 0

# %%
df.sex.value_counts().plot(kind='pie', autopct='%1.0f%%', legend=True, title="Gender Pie Chart")
plt.show()

# %%
df.sex.value_counts().plot(kind='bar',legend=True, title="Gender Bar Chart", color=['red', 'orange'])
plt.show()

# %% [markdown]
# ### Chest Pain Column

# %%
df.cp.value_counts()
# Out:
# 4    144
# 3     86
# 2     50
# 1     23
# Name: cp, dtype: int64

# %% [markdown]
# - Value 1: Stable
# - Value 2: Unstable
# - Value 3: Microvascular
# - Value 4: Variant

# %%
df.cp.value_counts().plot(kind='pie', autopct='%1.0f%%', figsize=(8,6), title="Chest Pain Experianced Pie Chart")
plt.show()

# %%
df.cp.value_counts().plot(kind='bar',legend=True, title="Chest Pain Experianced Bar Chart", color=['green', 'blue','orange', 'red'])
plt.show()

# %% [markdown]
# ### trestbps Column : The person's resting blood pressure

# %%
df.trestbps.unique()
# Out:
# array([145, 160, 120, 130, 140, 172, 150, 110, 132, 117, 135, 112, 105,
#        124, 125, 142, 128, 170, 155, 104, 180, 138, 108, 134, 122, 115,
#        118, 100, 200,  94, 165, 102, 152, 101, 126, 174, 148, 178, 158,
#        192, 129, 144, 123, 136, 146, 106, 156, 154, 114, 164], dtype=int64)

# %% [markdown]
# -  The person's resting blood pressure (mm Hg on admission to the hospital)

# %%
df.trestbps.plot(kind='kde', legend=True,figsize=(7,5), title="Blood Pressure Pie Chart")
plt.show()

# %%
df.trestbps.plot(kind='box', legend=True,figsize=(7,5), title="Blood Pressure Boxplot")
plt.show()

# %% [markdown]
# ### Cholesterol Column

# %%
df.chol.unique()
# Out:
# array([233, 286, 229, 250, 204, 236, 268, 354, 254, 203, 192, 294, 256,
#        263, 199, 168, 239, 275, 266, 211, 283, 284, 224, 206, 219, 340,
#        226, 247, 167, 230, 335, 234, 177, 276, 353, 243, 225, 302, 212,
#        330, 175, 417, 197, 198, 290, 253, 172, 273, 213, 305, 216, 304,
#        188, 282, 185, 232, 326, 231, 269, 267, 248, 360, 258, 308, 245,
#        270, 208, 264, 321, 274, 325, 235, 257, 164, 141, 252, 255, 201,
#        222, 260, 182, 303, 265, 309, 307, 249, 186, 341, 183, 407, 217,
#        288, 220, 209, 227, 261, 174, 281, 221, 205, 240, 289, 318, 298,
#        564, 246, 322, 299, 300, 293, 277, 214, 207, 223, 160, 394, 184,
#        315, 409, 244, 195, 196, 126, 313, 259, 200, 262, 215, 228, 193,
#        271, 210, 327, 149, 295, 306, 178, 237, 218, 242, 319, 166, 180,
#        311, 278, 342, 169, 187, 157, 176, 241, 131], dtype=int64)

# %% [markdown]
# - The person's cholesterol measurement in mg/dl

# %%
df.chol.plot(kind='kde', figsize=(8,6), legend=True, title="Cholesterol Distribution")
plt.show()

# %%
df.chol.plot(kind='box', figsize=(8,6), legend=True, title="Cholesterol Boxplot Chart")
plt.show()

# %% [markdown]
# ### Fasting Blood Sugar Column

# %%
df.fbs.value_counts()
# Out:
# 0    258
# 1     45
# Name: fbs, dtype: int64

# %% [markdown]
# #### The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)

# %%
df.fbs.value_counts().plot(kind="pie", autopct="%1.0f%%", title="Fasting Blood Sugar Pie Chart", legend=True, figsize=(8,6))
plt.show()

# %%
df.fbs.value_counts().plot(kind="bar",  title="Fasting Blood Sugar Bar Chart", figsize=(8,6),legend=True, color=["red","blue"])
plt.show()

# %% [markdown]
# ### Electrocardiographic Column

# %%
df.restecg.value_counts()
# Out:
# 0    151
# 2    148
# 1      4
# Name: restecg, dtype: int64

# %% [markdown]
# Resting electrocardiographic measurement
#    - 0 = normal
#    - 1 = having ST-T wave abnormality
#    - 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria

# %%
df.restecg.value_counts().plot(kind="pie", autopct="%1.0f%%", title="Electrocardiographic Pie Chart", legend=True, figsize=(8,6))
plt.show()

# %%
df.restecg.value_counts().plot(kind="bar",  title="Fasting Blood Sugar Bar Chart", figsize=(8,6),legend=True, color=["red","blue"])
plt.show()

# %% [markdown]
# ### Heart Rate Column

# %%
df.thalach.unique()
# Out:
# array([150, 108, 129, 187, 172, 178, 160, 163, 147, 155, 148, 153, 142,
#        173, 162, 174, 168, 139, 171, 144, 132, 158, 114, 151, 161, 179,
#        120, 112, 137, 157, 169, 165, 123, 128, 152, 140, 188, 109, 125,
#        131, 170, 113,  99, 177, 141, 180, 111, 143, 182, 156, 115, 149,
#        145, 146, 175, 186, 185, 159, 130, 190, 136,  97, 127, 154, 133,
#        126, 202, 103, 166, 164, 184, 124, 122,  96, 138,  88, 105, 194,
#        195, 106, 167,  95, 192, 117, 121, 116,  71, 118, 181, 134,  90],
#       dtype=int64)

# %% [markdown]
# - thalach: The person's maximum heart rate achieved

# %%
df.thalach.plot(kind='kde', legend=True, figsize=(7,5), title=("Heart Rate Distribution"))
plt.show()

# %%
df.thalach.plot(kind='box', legend=True, figsize=(7,5), title=("Heart Rate Boxplot Chart"))
plt.show()

# %% [markdown]
# ### Exercise Induced Angina Column

# %%
df.exang.value_counts()
# Out:
# 0    204
# 1     99
# Name: exang, dtype: int64

# %% [markdown]
# - exang: Exercise induced angina (1 = yes; 0 = no)

# %%
df.exang.value_counts().plot(kind="pie", autopct="%1.0f%%", legend=True,figsize=(7,5), title="Angina Pie Chart")
plt.show()

# %%
df.exang.value_counts().plot(kind="bar", color=["blue","red"], legend=True,figsize=(7,5), title="Angina Pie Chart")
plt.show()

# %% [markdown]
# ### oldpeak : ST Depression Column

# %%
df.oldpeak.unique()
# Out:
# array([2.3, 1.5, 2.6, 3.5, 1.4, 0.8, 3.6, 0.6, 3.1, 0.4, 1.3, 0. , 0.5,
#        1.6, 1. , 1.2, 0.2, 1.8, 3.2, 2.4, 2. , 2.5, 2.2, 2.8, 3. , 3.4,
#        6.2, 4. , 5.6, 2.9, 0.1, 2.1, 1.9, 4.2, 0.9, 1.1, 3.8, 0.7, 0.3,
#        4.4])

# %% [markdown]
# - oldpeak: ST depression induced by exercise relative to rest

# %%
df.oldpeak.plot(kind='kde', legend=True, figsize=(7,5), title=("ST Depression Distribution"))
plt.show()

# %%
df.oldpeak.plot(kind='box', legend=True, figsize=(7,5), title=("ST Depression Boxplot Chart"))
plt.show()

# %% [markdown]
# ### Slope Column

# %%
df.slope.value_counts()
# Out:
# 1    142
# 2    140
# 3     21
# Name: slope, dtype: int64

# %% [markdown]
# #### The slope of the peak exercise ST segment
#    - Value 1: Upsloping
#    - Value 2: Flat
#    - Value 3: Downsloping

# %%
df.slope.value_counts().plot(kind="pie", autopct="%1.0f%%",legend=True,title="Slope Pie Chart")
plt.show()

# %%
df.slope.value_counts().plot(kind="bar", legend=True,title="Slope Bar Chart", color=["orange","blue","green"])
plt.show()

# %% [markdown]
# ### ca : Major Vessels Column

# %%
df.ca.value_counts()
# Out:
#  0         176
#  1          65
#  2          38
#  3          20
# -100000      4
# Name: ca, dtype: int64

# %%
df.ca = df.ca.replace(-100000, 3)

# %%
df.ca.value_counts()
# Out:
# 0    176
# 1     65
# 2     38
# 3     24
# Name: ca, dtype: int64

# %% [markdown]
# - The number of major vessels (0-3)

# %%
df.ca.value_counts().plot(kind='pie', autopct="%1.0f%%", legend=True, title="Major Vessels Pie Charts")
plt.show()

# %%
df.ca.value_counts().plot(kind='bar', legend=True, title="Major Vessels Bar Charts", color=["orange","green","red","blue"])
plt.show()

# %% [markdown]
# ### Thalassemia Column

# %%
df.thal.value_counts()
# Out:
#  3         166
#  7         117
#  6          18
# -100000      2
# Name: thal, dtype: int64

# %%
df.thal = df.thal.replace(-100000,6)

# %%
df.thal.value_counts()
# Out:
# 3    166
# 7    117
# 6     20
# Name: thal, dtype: int64

# %% [markdown]
# #### A blood disorder called thalassemia
#    - 3 = normal
#    - 6 = fixed defect
#    - 7 = reversable defect

# %%
df.thal.value_counts().plot(kind="pie", autopct="%1.0ff%%", legend=True, title="Thalassemia Pie Chart", figsize=(7,6))
plt.show()

# %%
df.thal.value_counts().plot(kind="bar", color=["orange","green","blue"], legend=True, title="Thalassemia Pie Chart", figsize=(7,6))
plt.show()

# %% [markdown]
# ### Heart Disease Column

# %%
df.num.value_counts()
# Out:
# 0    164
# 1    139
# Name: num, dtype: int64

# %% [markdown]
# #### Heart Disease
#   -  0 = no
#   -  1 = yes

# %%
df.num.value_counts().plot(kind="pie", autopct="%1.0ff%%", legend=True, title="Heart Disease Pie Chart", figsize=(7,6))
plt.show()

# %%
df.num.value_counts().plot(kind="bar",legend=True,color=["green","red"], title="Heart Disease Pie Chart", figsize=(7,6))
plt.show()

# %% [markdown]
# ##### There are thirteen features in Dataset
#
#  - age: The person's age in years
#  - sex: The person's sex (1 = male, 0 = female)
#  - cp: The chest pain experienced
#            Value 1: Stable
#            Value 2: Unstable
#            Value 3: Microvascular
#            Value 4: Variant
#  - trestbps: The person's resting blood pressure (mm Hg on admission to the hospital)
#  - chol: The person's cholesterol measurement in mg/dl
#  - fbs: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
#  - restecg: Resting electrocardiographic measurement
#            0 = normal
#            1 = having ST-T wave abnormality
#            2 = showing probable or definite left ventricular hypertrophy by Estes' criteria
#  - thalach: The person's maximum heart rate achieved
#  - exang: Exercise induced angina (1 = yes; 0 = no)
#  - oldpeak: ST depression induced by exercise relative to rest
#  - slope: the slope of the peak exercise ST segment
#            Value 1: Upsloping
#            Value 2: Flat
#            Value 3: Downsloping
#  - ca: The number of major vessels (0-3)
#  - thal: A blood disorder called thalassemia
#            3 = normal
#            6 = fixed defect
#            7 = reversable defect
#  - num: Heart disease
#            0 = no
#            1 = yes

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
# creating function to convert numerical to categorical data


# age column
def ages(column):
    if column <35:
        return "Youngster"
    elif column >=35 and column <60:
        return "Senior Citizens"
    else:
        return "Super Senior Citizens"

# sex column
def sex_(column):
    if column == 1:
        return "Male"
    else:
        return "Female"

# cp column
def cp_(column):
    if column == 1:
        return "Stable"
    elif column == 2:
        return "Unstable"
    elif column == 3:
        return "Microvascular"
    else:
        return "Variant"

# trestbps column
def exang_(column):
    if column ==1:
        return "Yes"
    else:
        return "No"

# slope column
def slope_(column):
    if column == 1:
        return "Upsloping"
    elif column == 2:
        return "Flat"
    else:
        return "Downsloping"

# # ca column
# def ca(column):
#     if column == 0:
#         return "Arteries"
#     elif column == 1:
#         return "Arterioles"
#     elif column == 2:
#         return ""
#     elif column == 3:
#         return ""
#     else:
#         return ""

# thal column

def thal_(column):
    if column==3:
        return "Normal"
    elif column==6:
        return "Fixed Defect"
    elif column==7:
        return "Reversable Defect"

# num column
def num_(column):
    if column==1:
        return "Presence"
    else:
        return "Absense"

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
df1['ageC'] = df1['age'].apply(ages)
df1['sexC'] = df1['sex'].apply(sex_)
df1['cpC'] = df1['cp'].apply(cp_)
df1['exangC'] = df1['exang'].apply(exang_)
df1['slopeC'] = df1['slope'].apply(slope_)
df1['thalC'] = df1['thal'].apply(thal_)
df1['num'] = df1['num'].apply(num_)

# %%
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal       num                   ageC    sexC            cpC exangC  \
# 0   0     6   Absense  Super Senior Citizens    Male         Stable     No
# 1   3     3  Presence  Super Senior Citizens    Male        Variant    Yes
# 2   2     7  Presence  Super Senior Citizens    Male        Variant    Yes
# 3   0     3   Absense        Senior Citizens    Male  Microvascular     No
# 4   0     3   Absense        Senior Citizens  Female       Unstable     No
#
#         slopeC              thalC
# ...

# %% [markdown]
# # Univariant Analysis

# %%
df1.ageC.value_counts()
# Out:
# Senior Citizens          209
# Super Senior Citizens     91
# Youngster                  3
# Name: ageC, dtype: int64

# %%
sns.countplot(x=df1.ageC)
plt.show()

# %%
df1.ageC.value_counts().plot(kind='pie', autopct='%1.1f%%', explode=(0, 0, 0.1), shadow=True)
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.countplot(x='age', data=df)
plt.title('Population Age', fontsize=25)
plt.xlabel('Age', fontsize=20)
plt.ylabel('Count', fontsize=20)
plt.show()

# %%
df1.sexC.value_counts()
# Out:
# Male      206
# Female     97
# Name: sexC, dtype: int64

# %%
sns.countplot(x=df1.sex)
plt.show()

# %%
df1.sexC.value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True)
plt.show()

# %%
df1.cpC.value_counts()
# Out:
# Variant          144
# Microvascular     86
# Unstable          50
# Stable            23
# Name: cpC, dtype: int64

# %%
sns.countplot(x=df1.cpC)
plt.show()

# %%
df1.cpC.value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True)
plt.show()

# %%
df1.exangC.value_counts()
# Out:
# No     204
# Yes     99
# Name: exangC, dtype: int64

# %%
sns.countplot(x=df1.exang)
plt.show()

# %%
df1.exangC.value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True)
plt.show()

# %%
df1.slopeC.value_counts()
# Out:
# Upsloping      142
# Flat           140
# Downsloping     21
# Name: slopeC, dtype: int64

# %%
sns.countplot(x=df1.slopeC)
plt.show()

# %%
df1.slopeC.value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True)
plt.show()

# %%
df1.thalC.value_counts()
# Out:
# Normal               166
# Reversable Defect    117
# Fixed Defect          20
# Name: thalC, dtype: int64

# %%
sns.countplot(x=df1.thalC)
plt.show()

# %%
df1.thalC.value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True)
plt.show()

# %%
df1.num.value_counts()
# Out:
# Absense     164
# Presence    139
# Name: num, dtype: int64

# %%
sns.countplot(x=df1.num)
plt.show()

# %%
df1.num.value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True)
plt.show()

# %% [markdown]
# # Multi-Variant Analysis

# %%
sns.barplot(x='sexC', y='trestbps', data=df1)
plt.title("Blood Pressure", fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel("Person's Resting Blood Pressure (mm Hg)", fontsize=12)
plt.show()

# %%
sns.barplot(x='sexC', y='chol', data=df1)
plt.title("Cholestrol Level Based On Gender", fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel("Cholestrol", fontsize=15)
plt.show()

# %%
sns.barplot(x='num', y='chol', data=df1)
plt.title('Cholestrol VS Heart Disease', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Cholestrol', fontsize=15)
plt.show()

# %%
sns.barplot(x='num', y='trestbps', data=df1)
plt.title('Blood Pressure VS Heart Disease', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Blood Pressure', fontsize=15)
plt.show()

# %%
sns.lineplot(x='age', y='trestbps', data=df, color='g')
plt.title('Blood Pressure VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Blood Pressure', fontsize=15)
plt.show()

# %%
sns.lineplot(x='age', y='chol', data=df, color='r')
plt.title('Cholestrol VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Cholestrol', fontsize=15)
plt.show()

# %%
sns.lineplot(x='age', y='oldpeak', data=df, color='y')
plt.title('ST Depression VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('ST depression', fontsize=15)
plt.show()

# %%
sns.barplot(x='sex', y='oldpeak', data=df1)
plt.title('ST depression VS Heart Disease', fontsize=17)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('ST depression', fontsize=15)
plt.show()

# %%
sns.barplot(x='num', y='exang', data=df)
plt.title('Exercise With Angina VS Heart Disease', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Exercise With Angina', fontsize=15)
plt.show()

# %%
sns.barplot(x='sex', y='exang', data=df)
plt.title('Exercise With Angina VS Gender', fontsize=17)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('Exercise With Angina', fontsize=15)
plt.show()

# %%
sns.barplot(y='fbs', x='sex', data=df)
plt.title(' Fasting Blood Sugar VS Gender', fontsize=17)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('Fasting Blood Sugar', fontsize=15)
plt.show()

# %%
#Heatmap Creation using Seaborn

plt.figure(figsize=(16,9))
sns.heatmap(df.corr(), annot=True, linewidth=3)
plt.show()

# %%
X = df.iloc[:,:-1]

# %%
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope  ca  thal
# 0        3   0     6
# 1        2   3     3
# 2        2   2     7
# ...

# %%
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 298    1
# 299    1
# 300    1
# 301    1
# 302    0
# Name: num, Length: 303, dtype: int64

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 51)

# %%
X_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 173   62    0   4       140   394    0        2      157      0      1.2
# 176   52    1   4       108   233    1        0      147      0      0.1
# 276   66    0   3       146   278    0        2      152      0      0.0
# 143   64    1   3       125   309    0        0      131      1      1.8
# 272   46    1   4       140   311    0        0      120      1      1.8
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 222   39    0   3        94   199    0        0      179      0      0.0
# 16    48    1   2       110   229    0        0      168      0      1.0
# 197   45    0   4       138   236    0        2      152      1      0.2
# 224   63    0   4       108   269    0        0      169      1      1.8
# 57    41    1   4       110   172    0        2      158      0      0.0
#
#      slope  ca  thal
# 173      2   0     3
# 176      1   3     7
# 276      2   1     3
# ...

# %%
y_test
# Out:
# 260    0
# 211    1
# 104    1
# 108    1
# 135    0
#       ..
# 160    0
# 265    1
# 270    1
# 39     0
# 238    0
# Name: num, Length: 61, dtype: int64

# %%
print("X_train Shape is : ", X_train.shape)
print("X_test Shape is : ", X_test.shape)
print("y_train Shape is : ", y_train.shape)
print("y_test Shape is : ", y_test.shape)
# Out:
# X_train Shape is :  (242, 13)
# X_test Shape is :  (61, 13)
# y_train Shape is :  (242,)
# y_test Shape is :  (61,)

# %% [markdown]
# ## Data Preprocessing on Training Data

# %%
# scaling the numerical features

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# column names are (annoyingly) lost after Scaling
# (i.e. the dataframe is converted to a numpy ndarray)

X_train_rescaled = pd.DataFrame(scaler.fit_transform(X_train), 
                                    columns = X_train.columns, 
                                    index = X_train.index)

X_train_rescaled.head()
# Out:
#           age       sex        cp  trestbps      chol       fbs   restecg  \
# 173  0.807337 -1.477907  0.876126  0.503382  2.814847 -0.418040  0.959567
# 176 -0.302121  0.676632  0.876126 -1.354668 -0.278952  2.392117 -1.059696
# 276  1.251120 -1.477907 -0.163200  0.851766  0.585775 -0.418040  0.959567
# 143  1.029229  0.676632 -0.163200 -0.367579  1.181475 -0.418040 -1.059696
# 272 -0.967796  0.676632  0.876126  0.503382  1.219908 -0.418040 -1.059696
#
#       thalach     exang   oldpeak     slope        ca      thal
# 173  0.294470 -0.676632  0.176783  0.649662 -0.731182 -0.898040
# 176 -0.145689 -0.676632 -0.803626 -0.971144  2.337248  1.176668
# 276  0.074390 -0.676632 -0.892754  0.649662  0.291628 -0.898040
# 143 -0.849943  1.477907  0.711552  0.649662 -0.731182  1.176668
# 272 -1.334118  1.477907  0.711552  0.649662  1.314438  1.176668

# %%
scaler.var_, scaler.scale_
# Out:
# (array([8.12415306e+01, 2.15422444e-01, 9.25756437e-01, 2.96609726e+02,
#         2.70811750e+03, 1.26630695e-01, 9.81012226e-01, 5.16156017e+02,
#         2.15422444e-01, 1.25884024e+00, 3.80660474e-01, 9.55894406e-01,
#         3.71711290e+00]),
#  array([ 9.01340838,  0.46413623,  0.96216238, 17.22236122, 52.03957624,
#          0.35585207,  0.99046061, 22.71906726,  0.46413623,  1.1219805 ,
#          0.61697688,  0.97769853,  1.92798156]))

# %% [markdown]
# ## Preparing Test Data

# %%
X_test_rescaled = pd.DataFrame(scaler.transform(X_test), 
                                   columns = X_test.columns, 
                                   index = X_test.index)

X_test_rescaled.head()
# Out:
#           age       sex        cp  trestbps      chol      fbs   restecg  \
# 260 -1.189688 -1.477907 -0.163200 -0.774027 -0.106006 -0.41804 -1.059696
# 211 -1.855363  0.676632 -2.241851 -0.657899 -0.317384 -0.41804 -1.059696
# 104 -0.634959  0.676632 -0.163200 -0.657899 -1.143678 -0.41804 -1.059696
# 108  0.696391  0.676632  0.876126 -0.657899  0.239884 -0.41804 -1.059696
# 135  0.030716 -1.477907 -1.202526  0.213061  0.047723 -0.41804  0.959567
#
#       thalach     exang   oldpeak     slope        ca      thal
# 260 -0.057657 -0.676632 -0.625370  0.649662  0.291628 -0.898040
# 211  1.394867  1.477907  2.494114  0.649662 -0.731182  1.176668
# 104 -0.497816 -0.676632  0.889808  0.649662  2.337248  1.176668
# 108 -0.453800  1.477907  2.315858  0.649662  0.291628  1.176668
# 135  0.470534 -0.676632  0.355039  0.649662 -0.731182 -0.898040

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
import xgboost as xgb

from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# **Logistic Regression**

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_test_pred = lr.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.9016393442622951
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91        36
#            1       0.85      0.92      0.88        25
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61

# %% [markdown]
# **Decision Tree Classifier**

# %%
dt = DecisionTreeClassifier(max_depth=8)
dt.fit(X_train, y_train)
y_test_pred = dt.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.7704918032786885
#               precision    recall  f1-score   support
#
#            0       0.92      0.67      0.77        36
#            1       0.66      0.92      0.77        25
#
#     accuracy                           0.77        61
#    macro avg       0.79      0.79      0.77        61
# weighted avg       0.81      0.77      0.77        61

# %% [markdown]
# **Random Forest Classifier**

# %%
rf = RandomForestClassifier(n_estimators=20,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=25)
rf.fit(X_train, y_train)
y_test_pred = rf.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.8524590163934426
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87        36
#            1       0.77      0.92      0.84        25
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.86      0.85        61
# weighted avg       0.87      0.85      0.85        61

# %% [markdown]
# **MultinomialNB (Naive Bayes)**

# %%
mnb = MultinomialNB()
mnb.fit(X_train, y_train)
y_test_pred = mnb.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.819672131147541
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84        36
#            1       0.73      0.88      0.80        25
#
#     accuracy                           0.82        61
#    macro avg       0.82      0.83      0.82        61
# weighted avg       0.83      0.82      0.82        61

# %% [markdown]
# **BernoulliNB (Naive Bayes)**

# %%
bnb = BernoulliNB()
bnb.fit(X_train, y_train)
y_test_pred = bnb.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.8524590163934426
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87        36
#            1       0.77      0.92      0.84        25
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.86      0.85        61
# weighted avg       0.87      0.85      0.85        61

# %% [markdown]
# **KNeighbors Classifier**

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train, y_train)
y_test_pred = knn.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.7049180327868853
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77        36
#            1       0.68      0.52      0.59        25
#
#     accuracy                           0.70        61
#    macro avg       0.70      0.68      0.68        61
# weighted avg       0.70      0.70      0.70        61

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
gbc = GradientBoostingClassifier(n_estimators=35)
gbc.fit(X_train, y_train)
y_test_pred = gbc.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.8524590163934426
#               precision    recall  f1-score   support
#
#            0       0.97      0.78      0.86        36
#            1       0.75      0.96      0.84        25
#
#     accuracy                           0.85        61
#    macro avg       0.86      0.87      0.85        61
# weighted avg       0.88      0.85      0.85        61

# %% [markdown]
# **AdaBoost Classifier**

# %%
adc = GradientBoostingClassifier(n_estimators=15,learning_rate=1.0)
adc.fit(X_train, y_train)
y_test_pred = adc.predict(X_test)
print("Accuracy:" , accuracy_score(y_test, y_test_pred))
print(classification_report(y_test, y_test_pred))
# Out:
# Accuracy: 0.8032786885245902
#               precision    recall  f1-score   support
#
#            0       0.93      0.72      0.81        36
#            1       0.70      0.92      0.79        25
#
#     accuracy                           0.80        61
#    macro avg       0.81      0.82      0.80        61
# weighted avg       0.83      0.80      0.80        61

# %% [markdown]
# # Deep Learning
#
# ## An Artificial Neural Network (ANN)

# %%
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define the model architecture
model = Sequential()
model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=200, batch_size=4, validation_data=(X, y))

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/200
# 61/61 [==============================] - 1s 6ms/step - loss: 2.2947 - accuracy: 0.5868 - val_loss: 0.7401 - val_accuracy: 0.6799
# Epoch 2/200
# 61/61 [==============================] - 0s 3ms/step - loss: 0.9643 - accuracy: 0.6405 - val_loss: 0.7841 - val_accuracy: 0.6733
# Epoch 3/200
# 61/61 [==============================] - 0s 3ms/step - loss: 0.7370 - accuracy: 0.6694 - val_loss: 0.9401 - val_accuracy: 0.6337
# Epoch 4/200
# 61/61 [==============================] - 0s 3ms/step - loss: 0.7822 - accuracy: 0.6818 - val_loss: 1.1060 - val_accuracy: 0.4719
# Epoch 5/200
# 61/61 [==============================] - 0s 3ms/step - loss: 0.7198 - accuracy: 0.6736 - val_loss: 0.5835 - val_accuracy: 0.7360
# Epoch 6/200
# 61/61 [==============================] - 0s 3ms/step - loss: 0.6591 - accuracy: 0.7066 - val_loss: 0.5337 - val_accuracy: 0.7426
# Epoch 7/200
# ...

# %% [markdown]
# # Saving the Model (Serialization)

# %%
from pickle import dump

dump(scaler, open('models/standard_scaler.pkl', 'wb'))
dump(lr, open('models/lr_model.pkl', 'wb'))
dump(rf, open('models/rf_model.pkl', 'wb'))
dump(dt, open('models/dt_model.pkl', 'wb'))
dump(knn, open('models/knn_model.pkl', 'wb'))
dump(gbc, open('models/gbc_model.pkl', 'wb'))
dump(adc, open('models/adc_model.pkl', 'wb'))
dump(mnb, open('models/mnb_model.pkl', 'wb'))
dump(bnb, open('models/bnb_model.pkl', 'wb'))
dump(model, open('models/ann_model.pkl', 'wb'))

# %% [markdown]
# # Productionisation (Model Deserialization)

# %%
from pickle import load

# %%
# Loading pretrained model from pickle file

scaler = load(open('models/standard_scaler.pkl', 'rb'))
lr = load(open('models/lr_model.pkl', 'rb'))
rf = load(open('models/rf_model.pkl', 'rb'))
dt = load(open('models/dt_model.pkl', 'rb'))
knn = load(open('models/knn_model.pkl', 'rb'))
gbc = load(open('models/gbc_model.pkl', 'rb'))
adc = load(open('models/adc_model.pkl', 'rb'))
mnb = load(open('models/mnb_model.pkl', 'rb'))
bnb = load(open('models/bnb_model.pkl', 'rb'))
model = load(open('models/ann_model.pkl', 'rb'))

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
# Read the Query Data

print("Enter the Heart Disease Details")
age = float(input('Enter the age : '))
sex = float(input('Enter the sex : '))
cp = float(input('Enter the cp : '))
trestbps = float(input('Enter the trestbps : '))
chol = float(input('Enter the chol : '))
fbs = float(input('Enter the fbs : '))
restecg = float(input('Enter the restecg : '))
thalach = float(input('Enter the thalach : '))
exang = float(input('Enter the exang : '))
oldpeak = float(input('Enter the oldpeak : '))
slope = float(input('Enter the slope : '))
ca = float(input('Enter the ca : '))
thal = float(input('Enter the thal : '))
# Out:
# Enter the Heart Disease Details
# Enter the age : 27
# Enter the sex : 1
# Enter the cp : 4
# Enter the trestbps : 146
# Enter the chol : 234
# Enter the fbs : 1
# Enter the restecg : 2
# Enter the thalach : 153
# Enter the exang : 0
# Enter the oldpeak : 2.6
# Enter the slope : 2
# Enter the ca : 0
# Enter the thal : 6

# %% [markdown]
# # Converting the values to 2D Array

# %%
query_point = np.array([age, sex,cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal])

# %%
query_point
# Out:
# array([ 27. ,   1. ,   4. , 146. , 234. ,   1. ,   2. , 153. ,   0. ,
#          2.6,   2. ,   0. ,   6. ])

# %%
query_point = query_point.reshape(1, -1)

# %%
query_point
# Out:
# array([[ 27. ,   1. ,   4. , 146. , 234. ,   1. ,   2. , 153. ,   0. ,
#           2.6,   2. ,   0. ,   6. ]])

# %%
query_point_transformed = scaler.transform(query_point)

query_point_transformed
# Out:
# array([[-3.07576661,  0.67663234,  0.87612572,  0.85176599, -0.25973557,
#          2.39211668,  0.9595669 ,  0.11840639, -0.67663234,  1.42457655,
#          0.64966202, -0.73118248,  0.65799127]])

# %%
lr.predict(query_point_transformed)
# Out:
# array([1], dtype=int64)

# %% [markdown]
# ## Production Ready Code

# %%
# Read the Query Data

print("Enter the Heart Disease Details")
age = float(input('Enter the age : '))
sex = float(input('Enter the sex : '))
cp = float(input('Enter the cp : '))
trestbps = float(input('Enter the trestbps : '))
chol = float(input('Enter the chol : '))
fbs = float(input('Enter the fbs : '))
restecg = float(input('Enter the restecg : '))
thalach = float(input('Enter the thalach : '))
exang = float(input('Enter the exang : '))
oldpeak = float(input('Enter the oldpeak : '))
slope = float(input('Enter the slope : '))
ca = float(input('Enter the ca : '))
thal = float(input('Enter the thal : '))

query_point = np.array([age, sex,cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal])

query_point = query_point.reshape(1, -1)

query_point_transformed = scaler.transform(query_point)

lr.predict
